# %%
import pandas as pd
import numpy as np

# %%
path_data = '/share/pi/stamang/rise_pro/output/pipeline_test/'
df = pd.read_parquet(path_data + 'extracted_clean_assessment_column.parquet')
df['assessment_norm'] = df['assessment'].apply(lambda x: x.lower())
print(df.shape)
df.head()
# Out:
# (370, 22)
#                                   patid                               note_id  \
# 0  3d7e4841-6eb4-4b51-b702-6cabc980348c  018d8e07-e815-43eb-becc-d6bc84459221
# 1  3d7e4841-6eb4-4b51-b702-6cabc980348c  018d8e07-e815-43eb-becc-d6bc84459221
# 2  3d7e4841-6eb4-4b51-b702-6cabc980348c  018d8e07-e815-43eb-becc-d6bc84459221
# 3  3d7e4841-6eb4-4b51-b702-6cabc980348c  018d8e07-e815-43eb-becc-d6bc84459221
# 4  3d7e4841-6eb4-4b51-b702-6cabc980348c  018d8e07-e815-43eb-becc-d6bc84459221
#
#                             practice_id        date             tag  \
# 0  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17  INTERPRETATION
# 1  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              FS
# 2  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 3  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 4  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
#
#       assessment                 score    pos  \
# ...

# %%
df.loc[df['tag'] == 'INTERPRETATION'].shape
# Out:
# (27, 22)

# %%
df = df.assign(_shape=np.nan)
df = df.assign(score_updated=np.nan)
df = df.assign(score_updated_num=np.nan)
df.head()
# Out:
#                                   patid                               note_id  \
# 0  3d7e4841-6eb4-4b51-b702-6cabc980348c  018d8e07-e815-43eb-becc-d6bc84459221
# 1  3d7e4841-6eb4-4b51-b702-6cabc980348c  018d8e07-e815-43eb-becc-d6bc84459221
# 2  3d7e4841-6eb4-4b51-b702-6cabc980348c  018d8e07-e815-43eb-becc-d6bc84459221
# 3  3d7e4841-6eb4-4b51-b702-6cabc980348c  018d8e07-e815-43eb-becc-d6bc84459221
# 4  3d7e4841-6eb4-4b51-b702-6cabc980348c  018d8e07-e815-43eb-becc-d6bc84459221
#
#                             practice_id        date             tag  \
# 0  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17  INTERPRETATION
# 1  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              FS
# 2  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 3  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 4  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
#
#       assessment                 score    pos  \
# ...

# %%
df.assessment_norm.unique()
# Out:
# array(['no assessment', 'mdhaq', 'rapid 4', 'cdai', 'rapid 3', 'das 28',
#        'rapid3', 'das28', 'haq', 'rapid3/mdhaq', 'pain/mdhaq', 'fn/mdhaq',
#        'ptgl/mdhaq', 'mhaq', 'das', 'sdai'], dtype=object)

# %%
assessment_list = ['no assessment', 'rapid 4', 
       'ptgl/mdhaq', 'pain/mdhaq', 'fn/mdhaq', 'rapid 5','rapid 2']
df_short = df.loc[df['assessment_norm'].isin(assessment_list)]
print(df_short.shape)
df_short.head()
# Out:
# (60, 25)
#                                    patid  \
# 0   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 2   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 11  7e5e6513-53c9-4fa9-9ddf-58430b17e151
# 13  7e5e6513-53c9-4fa9-9ddf-58430b17e151
# 17  deded9af-2850-4865-988a-45d027d5c35a
#
#                                  note_id  \
# 0   018d8e07-e815-43eb-becc-d6bc84459221
# 2   018d8e07-e815-43eb-becc-d6bc84459221
# 11  0ab69b52-86db-45f1-a5c2-6247e6c614d0
# 13  0ab69b52-86db-45f1-a5c2-6247e6c614d0
# 17  18b54b9e-9a0c-4291-9f2d-0a5074d7a5a9
#
#                              practice_id        date             tag  \
# 0   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17  INTERPRETATION
# 2   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 11  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-05-08              DA
# 13  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-05-08  INTERPRETATION
# 17  04047457-3a7a-4d20-ad53-67bb5133ae83  2017-08-28              DA
#
# ...

# %%
df_short.tag.unique()
# Out:
# array(['INTERPRETATION', 'DA', 'FS'], dtype=object)

# %%
df_non_numerical = df.loc[df['score'] == 'No score']
print(df_non_numerical.shape)
df_non_numerical.head()
# Out:
# (86, 25)
#                                    patid  \
# 2   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 6   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 7   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 11  7e5e6513-53c9-4fa9-9ddf-58430b17e151
# 15  deded9af-2850-4865-988a-45d027d5c35a
#
#                                  note_id  \
# 2   018d8e07-e815-43eb-becc-d6bc84459221
# 6   018d8e07-e815-43eb-becc-d6bc84459221
# 7   018d8e07-e815-43eb-becc-d6bc84459221
# 11  0ab69b52-86db-45f1-a5c2-6247e6c614d0
# 15  18b54b9e-9a0c-4291-9f2d-0a5074d7a5a9
#
#                              practice_id        date tag assessment     score  \
# 2   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17  DA    RAPID 4  No score
# 6   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17  DA    RAPID 3  No score
# 7   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17  DA     DAS 28  No score
# 11  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-05-08  DA    RAPID 4  No score
# ...

# %%
df_non_numerical.tag.unique()
# Out:
# array(['DA', 'FS'], dtype=object)

# %%
df_updated = df.loc[(df['assessment_norm'].isin(assessment_list)) | (df['score'] == 'No score')]
print(df_updated.shape)
df_updated.head()
# Out:
# (132, 25)
#                                    patid  \
# 0   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 2   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 6   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 7   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 11  7e5e6513-53c9-4fa9-9ddf-58430b17e151
#
#                                  note_id  \
# 0   018d8e07-e815-43eb-becc-d6bc84459221
# 2   018d8e07-e815-43eb-becc-d6bc84459221
# 6   018d8e07-e815-43eb-becc-d6bc84459221
# 7   018d8e07-e815-43eb-becc-d6bc84459221
# 11  0ab69b52-86db-45f1-a5c2-6247e6c614d0
#
#                              practice_id        date             tag  \
# 0   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17  INTERPRETATION
# 2   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 6   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 7   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 11  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-05-08              DA
#
# ...

# %%
rapid3_scores = pd.read_parquet(path_data + 'rapid3_scores_processed.parquet').rename(columns={'shape':'_shape'})
print(rapid3_scores.shape)
rapid3_scores.head()
# Out:
# (130, 26)
#                                    patid  \
# 9   7e5e6513-53c9-4fa9-9ddf-58430b17e151
# 21  deded9af-2850-4865-988a-45d027d5c35a
# 22  71fd6547-2649-405b-8c6d-df6b9c0e0c42
# 35  2d6bfc35-4583-41d5-8429-8fa947de7fbd
# 36  6aba085b-d841-4532-b511-3b6f585389fb
#
#                                  note_id  \
# 9   0ab69b52-86db-45f1-a5c2-6247e6c614d0
# 21  18b54b9e-9a0c-4291-9f2d-0a5074d7a5a9
# 22  2abe32d7-d070-4a5f-8c46-01f2a76263b3
# 35  3a822578-490f-4e6a-8bfd-4149fbf810e5
# 36  3dafb671-41b7-455a-abbd-b5b849e94ec3
#
#                              practice_id        date tag assessment score  \
# 9   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-05-08  DA    RAPID 3    12
# 21  04047457-3a7a-4d20-ad53-67bb5133ae83  2017-08-28  DA    RAPID 3     4
# 22  04047457-3a7a-4d20-ad53-67bb5133ae83  2017-05-01  DA    RAPID 3  16.5
# 35  04047457-3a7a-4d20-ad53-67bb5133ae83  2017-05-19  DA    RAPID 3   6.7
# 36  04047457-3a7a-4d20-ad53-67bb5133ae83  2016-09-21  DA    RAPID 3   1.3
#
# ...

# %%
sdai_scores = pd.read_parquet(path_data + 'sdai_scores_processed.parquet').rename(columns={'shape':'_shape'})
print(sdai_scores.shape)
sdai_scores.head()
# Out:
# (1, 26)
#                                     patid  \
# 370  1b0b9f82-8ccd-4a4d-a2b9-1d2c5748f708
#
#                                   note_id  \
# 370  3891c50d-da7f-4401-ada9-91786ff06609
#
#                               practice_id        date tag assessment score  \
# 370  c9c197a0-01d2-4210-8d6e-2334cb74fddb  2018-03-28  DA       SDAI    25
#
#         pos                                       context_left  \
# 370  2080.0  [moderate, disabilities, ., and, the, clinical...
#
#                                          context_right  ...  \
# 370  [score, ), =, 25, which, means, the, disease, ...  ...
#
#      Practice_EHR_brand_2 year_inRISE   ucsf_rap3scale practiceid  \
# 370               No data   6/21/2017  no RAP3 records      684.0
#
#         interpretation assessment_norm _shape pro_range_nlp score_updated  \
# 370  moderate severity            sdai     dd           NaN            25
#
#      score_updated_num
# 370                 25
#
# [1 rows x 26 columns]

# %%
cdai_scores = pd.read_parquet(path_data + 'cdai_scores_processed.parquet').rename(columns={'shape':'_shape'})
print(cdai_scores.shape)
cdai_scores.head()
# Out:
# (74, 26)
#                                    patid  \
# 3   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 4   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 8   7e5e6513-53c9-4fa9-9ddf-58430b17e151
# 10  7e5e6513-53c9-4fa9-9ddf-58430b17e151
# 18  deded9af-2850-4865-988a-45d027d5c35a
#
#                                  note_id  \
# 3   018d8e07-e815-43eb-becc-d6bc84459221
# 4   018d8e07-e815-43eb-becc-d6bc84459221
# 8   0ab69b52-86db-45f1-a5c2-6247e6c614d0
# 10  0ab69b52-86db-45f1-a5c2-6247e6c614d0
# 18  18b54b9e-9a0c-4291-9f2d-0a5074d7a5a9
#
#                              practice_id        date tag assessment score  \
# 3   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17  DA       CDAI    10
# 4   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17  DA       CDAI   2.9
# 8   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-05-08  DA       CDAI     4
# 10  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-05-08  DA       CDAI   2.9
# 18  04047457-3a7a-4d20-ad53-67bb5133ae83  2017-08-28  DA       CDAI     7
#
# ...

# %%
#das_scores = pd.read_parquet(path_data + 'das_scores_processed_v3.parquet')
#print(das_scores.shape)
#das_scores.head()

# %%
das28_scores = pd.read_parquet(path_data + 'das28_scores_processed.parquet').rename(columns={'shape':'_shape'})
print(das28_scores.shape)
das28_scores.head()
# Out:
# (8, 26)
#                                     patid  \
# 12   7e5e6513-53c9-4fa9-9ddf-58430b17e151
# 43   6aba085b-d841-4532-b511-3b6f585389fb
# 51   da970c4b-1b98-4195-805c-3405c80f3e4b
# 123  69c44639-70ef-4499-a089-82fd8cb07088
# 256  b57e1689-9227-4b78-974e-69f27df5677a
#
#                                   note_id  \
# 12   0ab69b52-86db-45f1-a5c2-6247e6c614d0
# 43   3dafb671-41b7-455a-abbd-b5b849e94ec3
# 51   57c21888-f12c-43ca-9517-307c3c26daa3
# 123  dd902f2c-15db-4f1d-ac65-047a31693cac
# 256  109bd472-6095-4c38-a686-02de9ba94281
#
#                               practice_id        date tag assessment score  \
# 12   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-05-08  DA     DAS 28  1/28
# 43   04047457-3a7a-4d20-ad53-67bb5133ae83  2016-09-21  DA     DAS 28  1/28
# 51   04047457-3a7a-4d20-ad53-67bb5133ae83  2017-07-26  DA     DAS 28  2/28
# 123  04047457-3a7a-4d20-ad53-67bb5133ae83  2017-02-24  DA     DAS 28  3/28
# ...

# %%
haq_scores = pd.read_parquet(path_data + 'haq_scores_processed.parquet').rename(columns={'shape':'_shape'})
print(haq_scores.shape)
haq_scores.head()
# Out:
# (6, 26)
#                                     patid  \
# 258  b57e1689-9227-4b78-974e-69f27df5677a
# 260  d4ad52b9-859e-4a92-802f-461d95b596ac
# 266  d0e9c521-f0cc-425c-93d5-b29844211eea
# 313  4331c3f2-ed27-4ca7-965c-5713a16e5573
# 327  2509f8bc-46eb-474d-825c-2cd0302e4d22
#
#                                   note_id  \
# 258  109bd472-6095-4c38-a686-02de9ba94281
# 260  dd0bf6ab-e372-45d6-8281-daf7643d1420
# 266  5d78ae31-4c07-4c5a-9a62-01b3e98a4c67
# 313  b61047aa-8af1-4bec-806a-84967d5250a2
# 327  267974bb-d643-465a-ad25-75d9baaea76a
#
#                               practice_id        date tag assessment  score  \
# 258  ba1899f2-af56-4e57-86ef-c060333215d4  2017-03-23  FS        haq      1
# 260  ba1899f2-af56-4e57-86ef-c060333215d4  2016-06-07  FS        haq  0.125
# 266  5b34dabb-cb3a-45ee-a875-ac0be15e3e30  2016-01-26  FS        HAQ    121
# 313  372b66a6-efee-44db-8f3e-8a64c0d3a0f1  2016-01-04  FS        HAQ      1
# ...

# %%
haqii_scores = pd.read_parquet(path_data + 'haqii_scores_processed.parquet').rename(columns={'shape':'_shape'})
print(haqii_scores.shape)
haqii_scores.head()

# %%
mdhaq_scores = pd.read_parquet(path_data + 'mdhaq_scores_processed.parquet').rename(columns={'shape':'_shape'})
print(mdhaq_scores.shape)
mdhaq_scores.head()
# Out:
# (15, 26)
#                                    patid  \
# 1   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 14  7e5e6513-53c9-4fa9-9ddf-58430b17e151
# 16  deded9af-2850-4865-988a-45d027d5c35a
# 23  71fd6547-2649-405b-8c6d-df6b9c0e0c42
# 44  6aba085b-d841-4532-b511-3b6f585389fb
#
#                                  note_id  \
# 1   018d8e07-e815-43eb-becc-d6bc84459221
# 14  0ab69b52-86db-45f1-a5c2-6247e6c614d0
# 16  18b54b9e-9a0c-4291-9f2d-0a5074d7a5a9
# 23  2abe32d7-d070-4a5f-8c46-01f2a76263b3
# 44  3dafb671-41b7-455a-abbd-b5b849e94ec3
#
#                              practice_id        date tag assessment score  \
# 1   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17  FS      MDHAQ     3
# 14  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-05-08  FS      MDHAQ     4
# 16  04047457-3a7a-4d20-ad53-67bb5133ae83  2017-08-28  FS      MDHAQ     0
# 23  04047457-3a7a-4d20-ad53-67bb5133ae83  2017-05-01  FS      MDHAQ     5
# 44  04047457-3a7a-4d20-ad53-67bb5133ae83  2016-09-21  FS      MDHAQ   0.3
#
# ...

# %%
mhaq_scores = pd.read_parquet(path_data + 'mhaq_scores_processed.parquet').rename(columns={'shape':'_shape'})
print(mhaq_scores.shape)
mhaq_scores.head()
# Out:
# (4, 26)
#                                     patid  \
# 306  0729492b-2828-4b97-bb21-0fbe17126aaf
# 308  3e3ab77e-e4bc-459c-b2f2-47a57d1da705
# 311  3e3ab77e-e4bc-459c-b2f2-47a57d1da705
# 381  fd33b8ff-9737-441d-8f69-7e61b8ce68cc
#
#                                   note_id  \
# 306  230cc8d0-bdf1-4ecf-a5fa-82a86443b3e9
# 308  8d5528fb-2333-42b0-8c89-4ab825bc8d8d
# 311  8d5528fb-2333-42b0-8c89-4ab825bc8d8d
# 381  eb15725c-aa65-4136-9c29-a0dc0313db3b
#
#                               practice_id        date tag assessment score  \
# 306  372b66a6-efee-44db-8f3e-8a64c0d3a0f1  2017-05-25  FS       MHAQ     1
# 308  372b66a6-efee-44db-8f3e-8a64c0d3a0f1  2017-06-05  FS       MHAQ  2.25
# 311  372b66a6-efee-44db-8f3e-8a64c0d3a0f1  2017-06-05  FS       MHAQ     3
# 381  500dd1b6-95d9-45a4-b6e2-a136da420d1f  2017-12-06  FS       MHAQ     6
#
#         pos                                       context_left  \
# 306   950.0  [history, of, present, illness, *, *, ---, _, ...
# ...

# %%
cleaned_scores = rapid3_scores.append([sdai_scores, cdai_scores, das28_scores, 
                                      haq_scores, mdhaq_scores, mhaq_scores#,haqii_scores
                                      ], sort=False)
print(cleaned_scores.shape)
cleaned_scores.head()
# Out:
# (238, 26)
#                                    patid  \
# 9   7e5e6513-53c9-4fa9-9ddf-58430b17e151
# 21  deded9af-2850-4865-988a-45d027d5c35a
# 22  71fd6547-2649-405b-8c6d-df6b9c0e0c42
# 35  2d6bfc35-4583-41d5-8429-8fa947de7fbd
# 36  6aba085b-d841-4532-b511-3b6f585389fb
#
#                                  note_id  \
# 9   0ab69b52-86db-45f1-a5c2-6247e6c614d0
# 21  18b54b9e-9a0c-4291-9f2d-0a5074d7a5a9
# 22  2abe32d7-d070-4a5f-8c46-01f2a76263b3
# 35  3a822578-490f-4e6a-8bfd-4149fbf810e5
# 36  3dafb671-41b7-455a-abbd-b5b849e94ec3
#
#                              practice_id        date tag assessment score  \
# 9   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-05-08  DA    RAPID 3    12
# 21  04047457-3a7a-4d20-ad53-67bb5133ae83  2017-08-28  DA    RAPID 3     4
# 22  04047457-3a7a-4d20-ad53-67bb5133ae83  2017-05-01  DA    RAPID 3  16.5
# 35  04047457-3a7a-4d20-ad53-67bb5133ae83  2017-05-19  DA    RAPID 3   6.7
# 36  04047457-3a7a-4d20-ad53-67bb5133ae83  2016-09-21  DA    RAPID 3   1.3
#
# ...

# %%
df_updated = df_updated.append(cleaned_scores, sort=False)
print(df_updated.shape)
df_updated.head()
# Out:
# (370, 26)
#                                    patid  \
# 0   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 2   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 6   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 7   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 11  7e5e6513-53c9-4fa9-9ddf-58430b17e151
#
#                                  note_id  \
# 0   018d8e07-e815-43eb-becc-d6bc84459221
# 2   018d8e07-e815-43eb-becc-d6bc84459221
# 6   018d8e07-e815-43eb-becc-d6bc84459221
# 7   018d8e07-e815-43eb-becc-d6bc84459221
# 11  0ab69b52-86db-45f1-a5c2-6247e6c614d0
#
#                              practice_id        date             tag  \
# 0   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17  INTERPRETATION
# 2   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 6   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 7   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 11  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-05-08              DA
#
# ...

# %%
df_updated.columns
# Out:
# Index(['patid', 'note_id', 'practice_id', 'date', 'tag', 'assessment', 'score',
#        'pos', 'context_left', 'context_right', 'real_id', 'practice_type',
#        'rapid3range', 'ehr_brand', 'ucsf_practiceType', 'Practice_EHR_brand_1',
#        'Practice_EHR_brand_2', 'year_inRISE', 'ucsf_rap3scale', 'practiceid',
#        'interpretation', 'assessment_norm', '_shape', 'score_updated',
#        'score_updated_num', 'pro_range_nlp'],
#       dtype='object')

# %%
df_updated = df_updated[['patid', 'note_id', 'practice_id', 'date', 'tag', 'assessment', 'score','score_updated', 'interpretation',
       'pos', 'context_left', 'context_right', 'real_id', 'practice_type',
       'rapid3range', 'ehr_brand', 'ucsf_practiceType', 'Practice_EHR_brand_1',
       'Practice_EHR_brand_2', 'year_inRISE', 'ucsf_rap3scale', 'practiceid',
       #'extracted_tokens', 'token_length', 
                         'assessment_norm',
       '_shape', 'score_updated_num', 'pro_range_nlp']]
df_updated.head()
# Out:
#                                    patid  \
# 0   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 2   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 6   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 7   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 11  7e5e6513-53c9-4fa9-9ddf-58430b17e151
#
#                                  note_id  \
# 0   018d8e07-e815-43eb-becc-d6bc84459221
# 2   018d8e07-e815-43eb-becc-d6bc84459221
# 6   018d8e07-e815-43eb-becc-d6bc84459221
# 7   018d8e07-e815-43eb-becc-d6bc84459221
# 11  0ab69b52-86db-45f1-a5c2-6247e6c614d0
#
#                              practice_id        date             tag  \
# 0   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17  INTERPRETATION
# 2   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 6   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 7   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 11  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-05-08              DA
#
# ...

# %%
df_updated.loc[df_updated['score_updated'].isnull(), 'score_updated'] = df_updated['score']
df_updated.head()
# Out:
#                                    patid  \
# 0   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 2   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 6   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 7   3d7e4841-6eb4-4b51-b702-6cabc980348c
# 11  7e5e6513-53c9-4fa9-9ddf-58430b17e151
#
#                                  note_id  \
# 0   018d8e07-e815-43eb-becc-d6bc84459221
# 2   018d8e07-e815-43eb-becc-d6bc84459221
# 6   018d8e07-e815-43eb-becc-d6bc84459221
# 7   018d8e07-e815-43eb-becc-d6bc84459221
# 11  0ab69b52-86db-45f1-a5c2-6247e6c614d0
#
#                              practice_id        date             tag  \
# 0   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17  INTERPRETATION
# 2   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 6   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 7   04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17              DA
# 11  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-05-08              DA
#
# ...

# %% [markdown]
# #### Cleanup non-numerical extractions

# %%
df_updated.tag.unique()
# Out:
# array(['INTERPRETATION', 'DA', 'FS'], dtype=object)

# %%
df_updated.loc[df_updated['tag'] == 'INTERPRETATION']
# Out:
#                                     patid  \
# 0    3d7e4841-6eb4-4b51-b702-6cabc980348c
# 13   7e5e6513-53c9-4fa9-9ddf-58430b17e151
# 29   5cd2cfb6-cbc8-4046-a81e-7a3ef0ea65c2
# 41   6aba085b-d841-4532-b511-3b6f585389fb
# 49   da970c4b-1b98-4195-805c-3405c80f3e4b
# 50   da970c4b-1b98-4195-805c-3405c80f3e4b
# 54   e7d5fe1f-c759-447a-bcfe-9ee742bae4c6
# 68   97fd7002-bc01-4faf-8b94-949f48c0e533
# 73   97fd7002-bc01-4faf-8b94-949f48c0e533
# 80   811d0d8e-588f-46bc-a812-8d9c910aa556
# 84   9c3bf386-a76a-440a-bb3a-e12e0946b99c
# 99   ddba3124-ed26-4190-8f88-c0b5680f5590
# 119  5a90fa8a-3f33-4fb1-8288-1aca38ef24a7
# 190  dff7a687-daff-4d12-b1c0-83a2e36127f7
# 196  54171535-ad20-4b2f-b2d7-bb084e4e931d
# 207  dad14612-4f12-4c1e-b645-ab0d8e0ab04e
# 253  b57e1689-9227-4b78-974e-69f27df5677a
# 255  b57e1689-9227-4b78-974e-69f27df5677a
# 259  d4ad52b9-859e-4a92-802f-461d95b596ac
# 267  d0e9c521-f0cc-425c-93d5-b29844211eea
# 314  4331c3f2-ed27-4ca7-965c-5713a16e5573
# ...

# %%
df_updated.loc[(df_updated['interpretation'].notnull()) & (df_updated['tag'] != 'INTERPRETATION')]
# Out:
#                                     patid  \
# 112  cfc9c33b-2ca3-4f9f-9a7f-ef4db280cdff
# 181  3c602a1c-a4c1-40d7-af92-c798722587d6
# 372  14ebe42e-5b50-470d-aa72-17046d4ead78
# 382  90e891da-6fab-47c3-b0bc-f99249e6459e
# 370  1b0b9f82-8ccd-4a4d-a2b9-1d2c5748f708
# 4    3d7e4841-6eb4-4b51-b702-6cabc980348c
# 19   deded9af-2850-4865-988a-45d027d5c35a
# 26   71fd6547-2649-405b-8c6d-df6b9c0e0c42
# 33   2d6bfc35-4583-41d5-8429-8fa947de7fbd
# 37   6aba085b-d841-4532-b511-3b6f585389fb
# 63   71846efc-7df7-43cc-9255-0db11805483b
# 97   ddba3124-ed26-4190-8f88-c0b5680f5590
# 117  5a90fa8a-3f33-4fb1-8288-1aca38ef24a7
# 184  be290d0d-f201-4972-b921-1924b01cb40b
# 186  371bcdc9-125b-4e94-a5ae-6127863357de
# 188  8e09d7e5-7672-48f3-aad4-839aaedd86d7
# 192  78a2d55d-430b-4ab1-8a17-68c88a52fae5
# 194  54171535-ad20-4b2f-b2d7-bb084e4e931d
# 199  98d458da-bb3e-46d5-80ca-40625960b69d
# 209  dad14612-4f12-4c1e-b645-ab0d8e0ab04e
# 334  b9f04328-53cb-4177-8d1f-16362e188d6c
# ...

# %%
df_final = df_updated.loc[df_updated['tag'] != 'INTERPRETATION'].reset_index(drop=True)
print(df_final.shape)
df_final.head()
# Out:
# (343, 26)
#                                   patid                               note_id  \
# 0  3d7e4841-6eb4-4b51-b702-6cabc980348c  018d8e07-e815-43eb-becc-d6bc84459221
# 1  3d7e4841-6eb4-4b51-b702-6cabc980348c  018d8e07-e815-43eb-becc-d6bc84459221
# 2  3d7e4841-6eb4-4b51-b702-6cabc980348c  018d8e07-e815-43eb-becc-d6bc84459221
# 3  7e5e6513-53c9-4fa9-9ddf-58430b17e151  0ab69b52-86db-45f1-a5c2-6247e6c614d0
# 4  deded9af-2850-4865-988a-45d027d5c35a  18b54b9e-9a0c-4291-9f2d-0a5074d7a5a9
#
#                             practice_id        date tag assessment     score  \
# 0  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17  DA    RAPID 4  No score
# 1  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17  DA    RAPID 3  No score
# 2  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-01-17  DA     DAS 28  No score
# 3  04047457-3a7a-4d20-ad53-67bb5133ae83  2018-05-08  DA    RAPID 4  No score
# 4  04047457-3a7a-4d20-ad53-67bb5133ae83  2017-08-28  DA     DAS 28  No score
#
# ...

# %%
df_final.to_parquet(path_data + 'extracted_final.parquet')

# %%
df_updated.to_parquet(path_data + 'extracted_clean_assessment_column_processed.parquet')
